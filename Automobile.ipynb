# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# In C:\Users\Ahmed\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Ahmed\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Ahmed\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\Ahmed\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
Automobile_data = pd.read_csv('Automobile_data.csv')
Automobile_data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# 1. From the given dataset print the first and the last 5 rows.

# %%
#Printing the first 5 rows.
Automobile_data.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
#Printing the last 5 rows.
Automobile_data.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# 2. Clean the data and update the csv file.
# Replace all the column values which contain '?' and 'n.a' with NaN

# %%
Automobile_data.isnull().sum()
# Out:
# df_index            0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
for i in Automobile_data.loc[Automobile_data['price'].isnull()].index:
    print(Automobile_data.loc[i,['index','price']])
# Out:
# index     31
# price    NaN
# Name: 22, dtype: object
# index     32
# price    NaN
# Name: 23, dtype: object
# index     63
# price    NaN
# Name: 47, dtype: object

# %%
#Filling null values with NaN.
Automobile_data['price'].fillna(np.nan,inplace = True)

#Saving the data to a new csv file.
Automobile_data.to_csv('CarsData.csv')

# %%
new_auto = pd.read_csv('CarsData.csv')
new_auto
# Out:
#     Unnamed: 0  df_index      company   body-style  wheel-base  length  \
# 0            0         0  alfa-romero  convertible        88.6   168.8
# 1            1         1  alfa-romero  convertible        88.6   168.8
# 2            2         2  alfa-romero    hatchback        94.5   171.2
# 3            3         3         audi        sedan        99.8   176.6
# 4            4         4         audi        sedan        99.4   176.6
# ..         ...       ...          ...          ...         ...     ...
# 56          56        81   volkswagen        sedan        97.3   171.7
# 57          57        82   volkswagen        sedan        97.3   171.7
# 58          58        86   volkswagen        sedan        97.3   171.7
# 59          59        87        volvo        sedan       104.3   188.8
# 60          60        88        volvo        wagon       104.3   188.8
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# ...

# %%
#Deleting a column.
new_auto.drop('Unnamed: 0',axis = 1,inplace=True)

# %%
new_auto
# Out:
#     df_index      company   body-style  wheel-base  length engine-type  \
# 0          0  alfa-romero  convertible        88.6   168.8        dohc
# 1          1  alfa-romero  convertible        88.6   168.8        dohc
# 2          2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3          3         audi        sedan        99.8   176.6         ohc
# 4          4         audi        sedan        99.4   176.6         ohc
# ..       ...          ...          ...         ...     ...         ...
# 56        81   volkswagen        sedan        97.3   171.7         ohc
# 57        82   volkswagen        sedan        97.3   171.7         ohc
# 58        86   volkswagen        sedan        97.3   171.7         ohc
# 59        87        volvo        sedan       104.3   188.8         ohc
# 60        88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# ...

# %%
#Renaming a column.
new_auto.rename(columns={'df_index':'index'},inplace=True)
new_auto
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
#Setting a column as index.
new_auto.set_index('index')
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
new_auto.to_csv('CarsData.csv')

# %% [markdown]
# 3. Print the most expensive car company's name and price

# %%
#Retrieving the max price.
max_price = new_auto['price'].max()
max_price
# Out:
# 45400.0

# %%
#Passing the max price as condition to retrive the company name.
new_auto[new_auto['price']==max_price][['company','price']]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# 4. Print all toyota car details.

# %%
new_auto[new_auto['company']=='toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# 5. Count total cars per company.

# %%
vehicle_count = new_auto.groupby('company')['body-style'].count()
vehicle_count.sort_values(ascending = False)
# Out:
# company
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mitsubishi       4
# mercedes-benz    4
# audi             4
# porsche          3
# jaguar           3
# isuzu            3
# honda            3
# chevrolet        3
# alfa-romero      3
# volvo            2
# dodge            2
# Name: body-style, dtype: int64

# %% [markdown]
# 6. Find each company's hisghest priced car.

# %%
max_prices = new_auto.groupby('company')['price'].max()
max_prices
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %% [markdown]
# 7. Find the average mileage of each car company.

# %%
average_mileage = new_auto.groupby('company')['average-mileage'].mean()
average_mileage
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %% [markdown]
# 8. Sort all cars by price column

# %%
new_auto.sort_values('price',ascending = False)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
# ..    ...            ...          ...         ...     ...         ...
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 22     31          isuzu        sedan        94.5   155.9         ohc
# 23     32          isuzu        sedan        94.5   155.9         ohc
# 47     63        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# ...

# %% [markdown]
# 9. Concatenate 2 Dataframes and create a key for the two Dataframes.

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845,
171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price':
[29995, 23600, 61500 , 58900]}

# %%
GermanCarsDF = pd.DataFrame(GermanCars)
GermanCarsDF
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
JapaneseCarsDF = pd.DataFrame(japaneseCars)
JapaneseCarsDF
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
keys = ['German','Japanese']
CarsDF = pd.concat([GermanCarsDF,JapaneseCarsDF],keys = keys)
CarsDF
# Out:
#                 Company   Price
# German   0         Ford   23845
#          1     Mercedes  171995
#          2          BMV  135925
#          3         Audi   71400
# Japanese 0       Toyota   29995
#          1        Honda   23600
#          2       Nissan   61500
#          3  Mitsubishi    58900

# %% [markdown]
# 10. Create 2 Dataframes and merge them. Append the second Dataframe as a new column to the first Dataframe

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995,
135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141,
80, 182 , 160]}

# %%
Car_Price = pd.DataFrame(Car_Price)
Car_Price
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
car_Horsepower = pd.DataFrame(car_Horsepower)
car_Horsepower
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
result_df = pd.merge(Car_Price,car_Horsepower,on = 'Company')
result_df
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
